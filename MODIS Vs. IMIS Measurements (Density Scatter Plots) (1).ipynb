# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Function to process the folder and calculate yearly stats
def process_folder(folder_path, data_column, is_imis=False):
    all_stats = []
    
    # Loop through each file in the folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        # Skip directories and only process files
        if os.path.isdir(file_path):
            continue

        try:
            df = pd.read_csv(file_path)
            
            # Normalize column names to lowercase
            df.columns = [col.lower() for col in df.columns]
            
            # Check if the required columns are present
            required_columns = ['year', 'month', 'day', 'time']
            if not all(col in df.columns for col in required_columns) or (not is_imis and data_column.lower() not in df.columns):
                print(f"Skipping file {filename} as it does not contain the required columns.")
                continue
            
            # Create a 'datetime' column from year, month, day, time
            df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'time']].astype(str).agg('-'.join, axis=1), errors='coerce')
            df['Year'] = df['year']
            
            # Ensure the temperature data is numeric
            df[data_column.lower()] = pd.to_numeric(df[data_column.lower()], errors='coerce')
            
            # Group by year and calculate mean and standard deviation for each year
            yearly_stats = df.groupby('Year').agg({data_column.lower(): ['mean', 'std']}).reset_index()
            yearly_stats.columns = ['Year', 'Mean', 'Std']  # Rename columns
            all_stats.append(yearly_stats)
        
        except Exception as e:
            print(f"Error processing file {filename}: {e}")
            continue

    # Combine all stats from different files into a single DataFrame
    if all_stats:
        return pd.concat(all_stats).groupby('Year').agg({'Mean': 'mean', 'Std': 'mean'}).reset_index()
    else:
        print("No valid data found in the folder.")
        return pd.DataFrame(columns=['Year', 'Mean', 'Std'])

# Paths to the MODIS and IMIS data folders
modis_folder = r'E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MYD21A1N\Filtered_Data'
imis_folder = r'E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\analysis\interporelated data\NEW aqua night time\Filtered_Data'

# Process both MODIS and IMIS folders
modis_stats = process_folder(modis_folder, 'LST_1KM_scaled')
imis_stats = process_folder(imis_folder, 'TSS_30MIN_MEAN', is_imis=True)

# Merge the two datasets on 'Year'
if not modis_stats.empty and not imis_stats.empty:
    merged_stats = pd.merge(modis_stats, imis_stats, on='Year', suffixes=('_MODIS', '_IMIS'))
    
    # Calculate compatibility metrics
    pearson_corr, _ = pearsonr(merged_stats['Mean_MODIS'], merged_stats['Mean_IMIS'])
    mean_absolute_difference = (merged_stats['Mean_MODIS'] - merged_stats['Mean_IMIS']).abs().mean()

    # Plotting the merged data
    plt.figure(figsize=(12, 8))

    # MODIS Data
    plt.scatter(merged_stats['Year'], merged_stats['Mean_MODIS'], color='blue', label='MODIS Data')
    plt.fill_between(merged_stats['Year'], merged_stats['Mean_MODIS'] - merged_stats['Std_MODIS'], merged_stats['Mean_MODIS'] + merged_stats['Std_MODIS'], color='lightgray', label='MODIS Std Dev', alpha=0.5)

    # IMIS Data
    plt.errorbar(merged_stats['Year'], merged_stats['Mean_IMIS'], yerr=merged_stats['Std_IMIS'], fmt='o', color='red', label='IMIS Data', capsize=5)

    # Add labels, title, legend, grid, and metrics text
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('LST Mean', fontsize=14)
    
    plt.legend(title='Datasets', title_fontsize='13', fontsize='11')
    plt.grid(True)
    plt.xticks(range(2000, 2024, 2), fontsize=12)
    plt.yticks(fontsize=12)

    # Add compatibility metrics to the plot
    plt.text(0.05, 0.95, f"Pearson Correlation: {pearson_corr:.2f}\nMean Absolute Difference: {mean_absolute_difference:.2f}", 
             transform=plt.gca().transAxes, fontsize=12, verticalalignment='top', bbox=dict(facecolor='white', alpha=0.8))

    # Show plot
    plt.savefig(r'E:\all folders\STUDIES\UZH\master thesis\new results\MYDN VS IMIS.jpg', dpi=300, bbox_inches='tight')

    plt.show()
else:
    print("Insufficient data for analysis.")
# Out:
# Skipping file mean_temperatures.csv as it does not contain the required columns.
# Skipping file mean_temperature_trends_by_hour.csv as it does not contain the required columns.
# Skipping file Stations trends per hour.csv as it does not contain the required columns.
# Skipping file station_slopes.csv as it does not contain the required columns.
# Error processing file table_image_MODIS.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipping file mean_temperatures.csv as it does not contain the required columns.
# Skipping file station_slopes.csv as it does not contain the required columns.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import TheilSenRegressor
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np
import glob
import os

# Define the paths to the directories containing the MODIS and IMIS temperature files
modis_path = r'E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data'
imis_path = r'E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023'

def load_and_prepare_data(path, temp_column):
    """Load and prepare temperature data from CSV files in a given path."""
    files = glob.glob(os.path.join(path, '*.csv'))
    data_list = []
    
    for file in files:
        try:
            print(f"Processing file: {file}")
            
            df = pd.read_csv(file)
            print(f"Columns in file {file}: {df.columns.tolist()}")
            
            if temp_column in df.columns:
                if 'datetime' in df.columns:
                    df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
                elif all(col in df.columns for col in ['year', 'month', 'day', 'time']):
                    df['datetime'] = pd.to_datetime(
                        df[['year', 'month', 'day']].astype(str).agg('-'.join, axis=1) + ' ' + df['time'],
                        errors='coerce'
                    )
                else:
                    print(f"Neither 'datetime' column nor 'year', 'month', 'day', 'time' columns found in file {file}")
                    continue

                df.dropna(subset=['datetime'], inplace=True)
                df = df[['datetime', temp_column]]
                df['source'] = os.path.basename(file)
                data_list.append(df)
            else:
                print(f"Column {temp_column} not found in file {file}")
        except Exception as e:
            print(f"Failed to process file {file}: {e}")
    
    return pd.concat(data_list, ignore_index=True) if data_list else pd.DataFrame()

# Load temperature data
modis_df = load_and_prepare_data(modis_path, 'lst_1km_scaled')
imis_df = load_and_prepare_data(imis_path, 'TSS_30MIN_MEAN')

# Check if the dataframes are empty
if modis_df.empty or imis_df.empty:
    raise ValueError("One or both of the datasets are empty or did not contain the required columns.")

# Merge data on 'datetime' column
merged_df = pd.merge(modis_df, imis_df, on='datetime', suffixes=('_modis', '_imis'))

# Drop rows with NaN values
merged_df.dropna(subset=['lst_1km_scaled', 'TSS_30MIN_MEAN'], inplace=True)

# Sample a subset of the data to avoid memory issues
sampled_df = merged_df.sample(n=10000, random_state=1)

# Prepare data for plotting
X = sampled_df['TSS_30MIN_MEAN'].values.reshape(-1, 1)  # IMIS temperatures
y = sampled_df['lst_1km_scaled'].values  # MODIS temperatures

# Fit the robust regression model
reg = TheilSenRegressor().fit(X, y)
y_pred = reg.predict(X)

# Calculate R² and slope
r2 = r2_score(y, y_pred)
slope = reg.coef_[0]

# Calculate Accuracy (Mean Absolute Difference)
mad = np.median(np.abs(y - y_pred))

# Calculate Precision (Standard Deviation of Deviation)
deviation = y - sampled_df['TSS_30MIN_MEAN'].values
precision = np.std(deviation)

# Create the density scatter plot
fig, ax = plt.subplots(figsize=(10, 6))

hb = ax.hexbin(X.flatten(), y, gridsize=50, cmap='inferno', mincnt=1)
cb = fig.colorbar(hb, ax=ax)
cb.set_label('Density')

# Determine the x-axis range
x_min, x_max = ax.get_xlim()
x_range = np.linspace(x_min, x_max, 100)
y_range = reg.predict(x_range.reshape(-1, 1))

# Plot the regression line
ax.plot(x_range, y_range, color='red', linewidth=2, label=f'Regression Line\nR² = {r2:.2f}, Slope = {slope:.2f}')

# Set the axis limits
ax.set_xlim(-40, 40)
ax.set_ylim(-40, 40)

# Set titles and labels

ax.set_xlabel('IMIS Temperature')
ax.set_ylabel('MODIS Temperature')
ax.legend()

# Create an inset histogram for deviation
ax_inset = plt.axes([0.75, 0.155, 0.2, 0.2])
ax_inset.hist(deviation, bins=30, color='gray', alpha=0.7)
ax_inset.set_title('Deviation', fontsize=10)
ax_inset.set_xlabel('MODIS - IMIS', fontsize=8)
ax_inset.set_ylabel('Frequency', fontsize=8)
ax_inset.tick_params(axis='both', which='major', labelsize=8)
ax_inset.set_xlim(-20, 20)

# Add accuracy and precision text
accuracy_text = f"MAD: {mad:.2f}°C"
plt.text(0.05, 0.95, accuracy_text, transform=ax.transAxes, fontsize=10, verticalalignment='top')

plt.tight_layout()
plt.show()
# Out:
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\AMD2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\AMD2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ANV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ANV2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ANV3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ANV3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ARO2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ARO2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ARO3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ARO3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ATT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ATT2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BED3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BED3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BER2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BER2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BER3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BER3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BEV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BEV2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BOG2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\BOG2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CAM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CAM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CHA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CHA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CMA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\CMA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DAV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DAV2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DAV3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DAV3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DIA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DIA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DTR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\DTR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\EGH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\EGH2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ELM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ELM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ELS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ELS2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FAE2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FAE2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FIR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FIR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FIS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FIS2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FNH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FNH2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FUL2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\FUL2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GAD2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GAD2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GAN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GAN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GLA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GLA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOM3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOM3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GOR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GUT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\GUT2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ILI2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ILI2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\JUL2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\JUL2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KES2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KES2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KLO2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KLO2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KLO3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\KLO3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LAG2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LAG2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LAU2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LAU2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LUK2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\LUK2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MAE2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MAE2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperatures.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperatures.csv: ['station', 'mean_temperature']
# Column lst_1km_scaled not found in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperatures.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperature_trends_by_hour.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperature_trends_by_hour.csv: ['Hour', 'Trend', 'Station', 'SlopePerYear']
# Column lst_1km_scaled not found in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\mean_temperature_trends_by_hour.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MEI2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MEI2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MTR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MTR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MUN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\MUN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\NAR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\NAR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\NAS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\NAS2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBW2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBW2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBW3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OBW3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ORT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ORT2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OTT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\OTT2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PAR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PAR2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PMA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PMA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PUZ2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\PUZ2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ROA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ROA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SAA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SAA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCA2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCA3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCA3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCB2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCB2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SCH2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SIM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SIM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SLF2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SLF2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SMN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SMN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SPN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SPN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SPN3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\SPN3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\Stations trends per hour.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\Stations trends per hour.csv: ['Hour', 'AMD2', 'ANV2', 'ANV3', 'ARO2', 'ARO3', 'ATT2', 'BED3', 'BER2', 'BER3', 'BEV2', 'BOG2', 'CAM2', 'CHA2', 'CMA2', 'DAV2', 'DAV3', 'DIA2', 'DTR2', 'EGH2', 'ELM2', 'ELS2', 'FAE2', 'FIR2', 'FIS2', 'FNH2', 'FUL2', 'GAD2', 'GAN2', 'GLA2', 'GOM2', 'GOM3', 'GOR2', 'GUT2', 'ILI2', 'JUL2', 'KES2', 'KLO2', 'KLO3', 'LAG2', 'LAU2', 'LUK2', 'MAE2', 'MEI2', 'MTR2', 'MUN2', 'NAR2', 'NAS2', 'OBM2', 'OBW2', 'OBW3', 'ORT2', 'OTT2', 'PAR2', 'PMA2', 'PUZ2', 'ROA2', 'SAA2', 'SCA2', 'SCA3', 'SCB2', 'SCH2', 'SIM2', 'SLF2', 'SMN2', 'SPN2', 'SPN3', 'STH2', 'STN2', 'TAM2', 'TAM3', 'TIT2', 'TRU2', 'TUJ2', 'TUM2', 'URS2', 'VAL2', 'VDS2', 'VIN2', 'WFJ2', 'ZER2']
# Column lst_1km_scaled not found in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\Stations trends per hour.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\station_slopes.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\station_slopes.csv: ['Station', 'Slope (Trend)']
# Column lst_1km_scaled not found in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\station_slopes.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\STH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\STH2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\STN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\STN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TAM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TAM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TAM3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TAM3.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TIT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TIT2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TRU2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TRU2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TUJ2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TUJ2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TUM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\TUM2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\URS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\URS2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VAL2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VAL2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VDS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VDS2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VIN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\VIN2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\WFJ2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\WFJ2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ZER2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\MODIS DATA\Actual Data\MOD21A1D\Filtered_Data\ZER2.csv: ['system:index', 'lst_1km', 'lst_1km_scaled', 'view_angle', 'view_angle_scaled', 'view_time', 'view_time_scaled', 'date', 'label', '.geo', 'year', 'month', 'day', 'time', 'datetime']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\AMD2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\AMD2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ANV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ANV2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ANV3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ANV3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ARO2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ARO2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ARO3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ARO3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ATT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ATT2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BED3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BED3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BER2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BER2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BER3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BER3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BEV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BEV2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BOG2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\BOG2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CAM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CAM2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CHA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CHA2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CMA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\CMA2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DAV2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DAV2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DAV3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DAV3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DIA2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DIA2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DTR2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\DTR2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\EGH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\EGH2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ELM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ELM2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ELS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ELS2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\FAE2.csv
# ...
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SCB2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SCB2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SCH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SCH2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SIM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SIM2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SLF2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SLF2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SMN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SMN2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SPN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SPN2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SPN3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\SPN3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour.csv: ['hours', 'AMD2', 'ANV2', 'ANV3', 'ARO2', 'ARO3', 'ATT2', 'BED3', 'BER2', 'BER3', 'BEV2', 'BOG2', 'CAM2', 'CHA2', 'CMA2', 'DAV2', 'DAV3', 'DIA2', 'DTR2', 'EGH2', 'ELM2', 'ELS2', 'FAE2', 'FIR2', 'FIS2', 'FNH2', 'FUL2', 'GAD2', 'GAN2', 'GLA2', 'GOM2', 'GOM3', 'GOR2', 'GUT2', 'ILI2', '2-Jul', 'KES2', 'KLO2', 'KLO3', 'LAG2', 'LAU2', 'LUK2', 'MAE2', 'MEI2', 'MTR2', 'MUN2', 'NAR2', 'NAS2', 'OBM2', 'OBW2', 'OBW3', 'ORT2', 'OTT2', 'PAR2', 'PMA2', 'PUZ2', 'ROA2', 'SAA2', 'SCA2', 'SCA3', 'SCB2', 'SCH2', 'SIM2', 'SLF2', 'SMN2', 'SPN2', 'SPN3', 'STH2', 'STN2', 'TAM2', 'TAM3', 'TIT2', 'TRU2', 'TUJ2', 'TUM2', 'URS2', 'VAL2', 'VDS2', 'VIN2', 'WFJ2', 'ZER2']
# Column TSS_30MIN_MEAN not found in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour_filtered.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour_filtered.csv: ['Unnamed: 0', 'AMD2', 'ANV2', 'ANV3', 'ARO2', 'ARO3', 'ATT2', 'BED3', 'BER2', 'BER3', 'BEV2', 'BOG2', 'CAM2', 'CHA2', 'CMA2', 'DAV2', 'DAV3', 'DIA2', 'DTR2', 'EGH2', 'ELM2', 'ELS2', 'FAE2', 'FIR2', 'FIS2', 'FNH2', 'FUL2', 'GAD2', 'GAN2', 'GLA2', 'GOM2', 'GOM3', 'GOR2', 'GUT2', 'ILI2', '2-Jul', 'KES2', 'KLO2', 'KLO3', 'LAG2', 'LAU2', 'LUK2', 'MAE2', 'MEI2', 'MTR2', 'MUN2', 'NAR2', 'NAS2', 'OBM2', 'OBW2', 'OBW3', 'ORT2', 'OTT2', 'PAR2', 'PMA2', 'PUZ2', 'ROA2', 'SAA2', 'SCA2', 'SCA3', 'SCB2', 'SCH2', 'SIM2', 'SLF2', 'SMN2', 'SPN2', 'SPN3', 'STH2', 'STN2', 'TAM2', 'TAM3', 'TIT2', 'TRU2', 'TUJ2', 'TUM2', 'URS2', 'VAL2', 'VDS2', 'VIN2', 'WFJ2', 'ZER2', 'hour']
# Column TSS_30MIN_MEAN not found in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\Stations trends per hour_filtered.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\station_slopes.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\station_slopes.csv: ['Station', 'Slope (Trend)']
# Column TSS_30MIN_MEAN not found in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\station_slopes.csv
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\STH2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\STH2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\STN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\STN2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TAM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TAM2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TAM3.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TAM3.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TIT2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TIT2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TRU2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TRU2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TUJ2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TUJ2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TUM2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\TUM2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\URS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\URS2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VAL2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VAL2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VDS2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VDS2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VIN2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\VIN2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\WFJ2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\WFJ2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# Processing file: E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ZER2.csv
# Columns in file E:\all folders\STUDIES\UZH\master thesis\IMIS data\new data\new processed data\TSS_30MIN_MEAN_files\Stations covering 2000till 2023\ZER2.csv: ['station_code', 'measure_date', 'hyear', 'TA_30MIN_MEAN', 'VW_30MIN_MEAN', 'VW_30MIN_MAX', 'DW_30MIN_MEAN', 'RH_30MIN_MEAN', 'DW_30MIN_SD', 'HS', 'TS0_30MIN_MEAN', 'TS25_30MIN_MEAN', 'TS50_30MIN_MEAN', 'TS100_30MIN_MEAN', 'RSWR_30MIN_MEAN', 'TSS_30MIN_MEAN', 'year', 'month', 'day', 'time']
# C:\Users\Grandiose\AppData\Local\Temp\ipykernel_9496\226553684.py:123: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import TheilSenRegressor
from sklearn.metrics import r2_score
import matplotlib.colors as mcolors

# Prepare data
X = sampled_df['TSS_30MIN_MEAN'].values.reshape(-1, 1)  # IMIS temperatures
y = sampled_df['lst_1km_scaled'].values  # MODIS temperatures

# Fit robust regression model
reg = TheilSenRegressor().fit(X, y)
y_pred = reg.predict(X)

# Calculate R² and slope
r2 = r2_score(y, y_pred)
slope = reg.coef_[0]

# Calculate Accuracy (Mean Absolute Difference)
mad = np.median(np.abs(y - y_pred))

# Calculate Deviation
deviation = y - sampled_df['TSS_30MIN_MEAN'].values

# Create custom colormap (Black → Dark Blue)
cmap = mcolors.LinearSegmentedColormap.from_list("black_blue", ["black", "darkblue", "blue"], N=256)

# Create density scatter plot
fig, ax = plt.subplots(figsize=(8, 8))

hb = ax.hexbin(X.flatten(), y, gridsize=80, cmap=cmap, mincnt=1, linewidths=0.2, edgecolors='none')

# Determine the x-axis range
x_min, x_max = -40, 40
x_range = np.linspace(x_min, x_max, 100)
y_range = reg.predict(x_range.reshape(-1, 1))

# Regression line
ax.plot(x_range, y_range, color='red', linewidth=2, label=f'Regression Line\nR² = {r2:.2f}, Slope = {slope:.2f}')

# Colorbar for density scale
cb = plt.colorbar(hb, ax=ax, label='Point Density')

# Set axis limits
ax.set_xlim(x_min, x_max)
ax.set_ylim(x_min, x_max)

# Titles and labels

ax.set_xlabel('IMIS LST (°C)', fontsize=12)
ax.set_ylabel('MOD21A1D LST (°C)', fontsize=12)

ax.grid(True, linestyle='--', alpha=0.5)
ax.legend()

# Calculate the deviation between MODIS and IMIS temperatures
deviation = y - sampled_df['TSS_30MIN_MEAN'].values

mean_deviation = np.mean(deviation)
mean_text = f"Mean_Deviation: {mean_deviation:.2f}°C"

# Inset histogram for deviation
ax_inset = plt.axes([0.54, 0.115, 0.23, 0.2])
ax_inset.hist(deviation, bins=30, color='gray', alpha=0.7)
ax_inset.set_title('Deviation', fontsize=10)
ax_inset.set_xlabel('MODIS - IMIS', fontsize=8)
ax_inset.set_ylabel('Frequency', fontsize=8)
ax_inset.tick_params(axis='both', labelsize=8)
ax_inset.set_xlim(-20, 20)
ax_inset.text(0.05, 0.95, mean_text, transform=ax_inset.transAxes, fontsize=8, verticalalignment='top')
# Add MAD text
plt.text(0.1, 0.91, f"MAD: {mad:.2f}°C", transform=ax.transAxes, fontsize=10, verticalalignment='top')

plt.tight_layout()
plt.savefig(r"E:\all folders\STUDIES\UZH\master thesis\new results\MODD with hist.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Grandiose\AppData\Local\Temp\ipykernel_9496\685465731.py:75: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
